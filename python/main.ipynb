# %%
import mitsuba as mi
mi.set_variant('cuda_ad_rgb')

# %%
scene = mi.load_file('../assets/Scenes/cbox.xml')

img = mi.render(scene)
mi.util.write_bitmap('out.png', img, quality=1)
mi.Bitmap(img)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = float32,
#   size = [256, 256],
#   srgb_gamma = 0,
#   struct = Struct<12>[
#     float32 R; // @0, premultiplied alpha
#     float32 G; // @4, premultiplied alpha
#     float32 B; // @8, premultiplied alpha
#   ],
#   data = [ 768 KiB of image data ]
# ]

# %%
scene = mi.load_file('../assets/Scenes/dragon/scene_onesided.xml')
img = mi.render(scene)
mi.util.write_bitmap('out.png', img)
mi.Bitmap(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 scene = mi.load_file('../assets/Scenes/dragon/scene_onesided.xml')
#       2 img = mi.render(scene)
#       3 mi.util.write_bitmap('out.png', img)
#
# NameError: name 'mi' is not defined

# %%
scene = mi.load_file('../assets/Scenes/additional_scenes/veach-mis/scene.xml')
img = mi.render(scene)
mi.util.write_bitmap('out.png', img)
mi.Bitmap(img)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = float32,
#   size = [1280, 720],
#   srgb_gamma = 0,
#   struct = Struct<12>[
#     float32 R; // @0, premultiplied alpha
#     float32 G; // @4, premultiplied alpha
#     float32 B; // @8, premultiplied alpha
#   ],
#   data = [ 10.5 MiB of image data ]
# ]
