# %%
import mitsuba as mi
mi.set_variant('cuda_ad_rgb')

# %%
scene = mi.load_file('../assets/Scenes/cbox.xml')
img = mi.render(scene, spp=256)
mi.util.write_bitmap('out.png', img)
mi.Bitmap(img)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = float32,
#   size = [256, 256],
#   srgb_gamma = 0,
#   struct = Struct<12>[
#     float32 R; // @0, premultiplied alpha
#     float32 G; // @4, premultiplied alpha
#     float32 B; // @8, premultiplied alpha
#   ],
#   data = [ 768 KiB of image data ]
# ]

# %%
# direct lighting
scene = mi.load_file('../assets/Scenes/cbox.xml')

img = mi.render(scene, spp=16)
mi.util.write_bitmap('direct.png', img)

# %%
scene = mi.load_file('../assets/Scenes/simple.xml')
img = mi.render(scene)
mi.Bitmap(img)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = float32,
#   size = [256, 256],
#   srgb_gamma = 0,
#   struct = Struct<12>[
#     float32 R; // @0, premultiplied alpha
#     float32 G; // @4, premultiplied alpha
#     float32 B; // @8, premultiplied alpha
#   ],
#   data = [ 768 KiB of image data ]
# ]
